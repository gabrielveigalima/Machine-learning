# %% [markdown]
# # Prever valor do prêmio da mega-sena da virada 2019

# %%
# Importando Matplotlib e Numpy
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
valor = [[244784099.15],[224677860.07],[263295552.66],[246533514.19],[220948549.30],[306718743.71]]
ano   = [[2012],[2013],[2014],[2015],[2016],[2011]]

# %%
valor = [[244784099.15],[224677860.07],[263295552.66],[246533514.19],[220948549.30]]
ano   = [[2012],[2013],[2014],[2015],[2016],[2018]]

# %%
plt.figure()
plt.xlabel('Ano')
plt.ylabel('Valor(R$)')
plt.title('Ano x Valor')
plt.plot(ano, valor)
plt.grid(True)
plt.show()

# %%
# Importando o módulo de Regressão Linear do scikit-learn
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()

# %%
# Treinando o modelo
modelo.fit(ano, valor)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
import numpy as np

# %%
valor_2018 = modelo.predict([2018][0])

# %%
print("O prêmio em 2018 será de: R$%.2f" % valor_2018)
# Out:
# O prêmio em 2018 será de: R$279219812.69

# %%
valor.append([np.around(valor_2018[0][0],2)])
ano.append([2018])

# %%
print(len(valor))
print(len(ano))
# Out:
# 7
# 7

# %%
#Grafico com a nova projeção
plt.figure()
plt.xlabel('Ano')
plt.ylabel('Valor(R$)')
plt.title('Ano x Valor')
plt.plot(ano, valor)
plt.grid(True)
plt.show()
